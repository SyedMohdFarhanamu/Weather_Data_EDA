# %% [markdown]
# ## Directions
# - The data required for this task has been provided in the file 'data.csv'
# - Read the questions provided for each cell and assign your answers to respective variables provided in the following cell.
# - If answers are floating point numbers round of updo two floating point after the decimal
#   - for example 10.546 should be read as 10.55, 10.544 as 10.54 and 10.1 as 10.10
# - pandas and numpy packages are preinstalled for this task which should be sufficient to complete this task.
# - If you need any other additional package run !pip3 install <package_name> --user in a new cell.
# - You can either try out the solution in the same notebook or free to create additional notebook, but make sure you come back to this notebook to answer the questions.
# - Please dont change variable name meant to assign your answers.
# - You can create a new notebook to write your scripts for EDA and use this notebook to assign the answers.

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('data.csv')
df
# Out:
#              Day  Average temperature (°F)  Average humidity (%)  \
# 0      1/01/2009                      37.8                    35
# 1      2/01/2009                      43.2                    32
# 2      3/01/2009                      25.7                    60
# 3      4/01/2009                       9.3                    67
# 4      5/01/2009                      23.5                    30
# ...          ...                       ...                   ...
# 3275  24/10/2018                      45.9                    53
# 3276  25/10/2018                      46.7                    40
# 3277  26/10/2018                      48.4                    35
# 3278  27/10/2018                      53.3                    37
# 3279  28/10/2018                      49.4                    48
#
#       Average dewpoint (°F)  Average barometer (in)  Average windspeed (mph)  \
# 0                      12.7                    29.7                     26.4
# 1                      14.7                    29.5                     12.8
# 2                      12.7                    29.7                      8.3
# 3                       0.1                    30.4                      2.9
# 4                      -5.3                    29.9                     16.7
# ...                     ...                     ...                      ...
# 3275                   27.5                    29.8                      2.7
# 3276                   22.7                    29.8                      4.5
# 3277                   21.6                    29.8                      9.7
# 3278                   26.6                    29.8                     10.3
# 3279                   25.2                    29.9                      5.3
#
#       Average gustspeed (mph)  Average direction (°deg)  \
# 0                        36.8                       274
# 1                        18.0                       240
# 2                        12.2                       290
# 3                         4.5                        47
# 4                        23.1                       265
# ...                       ...                       ...
# 3275                      4.6                       282
# 3276                      7.2                       283
# 3277                     14.4                       283
# 3278                     14.8                       282
# 3279                      7.6                       282
#
#       Rainfall for month (in)  Rainfall for year (in)  \
# 0                        0.00                    0.00
# 1                        0.00                    0.00
# 2                        0.00                    0.00
# 3                        0.00                    0.00
# 4                        0.00                    0.00
# ...                       ...                     ...
# 3275                     0.85                    6.86
# 3276                     0.85                    6.86
# 3277                     0.85                    6.86
# 3278                     0.85                    6.86
# 3279                     0.85                    6.86
#
#       Maximum rain per minute   Maximum temperature (°F)  \
# 0                          0.0                      40.1
# 1                          0.0                      52.8
# 2                          0.0                      41.2
# 3                          0.0                      19.4
# 4                          0.0                      30.3
# ...                        ...                       ...
# 3275                       0.0                      57.3
# 3276                       0.0                      61.8
# 3277                       0.0                      58.7
# 3278                       0.0                      64.5
# 3279                       0.0                      67.3
#
#       Minimum temperature (°F)  Maximum humidity (%)  Minimum humidity (%)  \
# 0                         34.5                    44                    27
# 1                         37.5                    43                    16
# 2                          6.7                    89                    35
# 3                         -0.0                    79                    35
# 4                         15.1                    56                    13
# ...                        ...                   ...                   ...
# 3275                      35.9                    81                    23
# 3276                      35.0                    60                    19
# 3277                      42.6                    48                    19
# 3278                      38.3                    78                    24
# 3279                      30.9                    90                    19
#
#       Maximum pressure   Minimum pressure   Maximum windspeed (mph)  \
# 0                29.762             29.596                     41.4
# 1                29.669             29.268                     35.7
# 2                30.232             29.260                     25.3
# 3                30.566             30.227                     12.7
# 4                30.233             29.568                     38.0
# ...                 ...                ...                      ...
# 3275             29.947             29.710                     12.7
# 3276             29.933             29.682                     13.8
# 3277             29.979             29.759                     20.7
# 3278             29.935             29.650                     28.8
# 3279             30.040             29.663                     18.4
#
#       Maximum gust speed (mph)  Maximum heat index (°F)
# 0                         59.0                     40.1
# 1                         51.0                     52.8
# 2                         38.0                     41.2
# 3                         20.0                     32.0
# 4                         53.0                     32.0
# ...                        ...                      ...
# 3275                      19.6                     57.2
# 3276                      19.6                     61.8
# 3277                      31.1                     58.7
# 3278                      38.0                     64.5
# 3279                      25.3                     67.3
#
# [3280 rows x 20 columns]

# %% [markdown]
# ### What is the standard deviation of maximum windspeed across all the days
# * NOTE ws_std should be the type of float

# %%
ws_std=round(df['Maximum windspeed (mph)'].std(),2)
ws_std
# Out:
# 13.06

# %% [markdown]
# ### What is the difference between 50th percentile and 75th percentile of average temperature
# * NOTE p_range should be the type of float

# %%
p=round(df['Average temperature (°F)'].quantile(.75) - df['Average temperature (°F)'].quantile(),2)
p_range = p.item()
p_range
# Out:
# 12.2

# %% [markdown]
# ### What is the pearson correlation between average dew point and average temperature
# * NOTE corr should be the type of float

# %%
cor=round(df['Average dewpoint (°F)'].corr(df['Average temperature (°F)']),2)
corr = cor.item()
corr
# Out:
# 0.76

# %% [markdown]
# ### Out of all the available records which month has the lowest average humidity.
# * Assign your answer as month index, for example if its July index is 7
# * NOTE dew_month should be the type of float

# %%
import datetime
hum_min = df.loc[df['Average humidity (%)'].min()]
whole_date =hum_min['Day']
dew_month = datetime.datetime.strptime(whole_date,"%d/%m/%Y").month
dew_month
# Out:
# 1

# %% [markdown]
# ### Which month has the highest median for maximum_gust_speed out of all the available records. Also find the repective value
# * hint: group by month
# * max_gust_value should be type of float
# * max_gust_month should be type of float

# %%
import datetime as dt
df['Date'] = pd.to_datetime(df['Day'],format ="%d/%m/%Y")
df['month_index'] = df['Date'].dt.month
max_gust_m =df.groupby(['month_index'])
max_gust_mon =max_gust_m['Maximum gust speed (mph)'].median()
max_gust_month = max_gust_mon.idxmax().item()
max_gust_value = max_gust_mon.max()

max_gust_month, max_gust_value
# Out:
# (2, 34.5)

# %% [markdown]
# ### Determine the average temperature between the months of March 2010 to May 2012 (including both the months)
# * NOTE avg_temp should be of type of float

# %%
import datetime as dt
df['Date'] = pd.to_datetime(df['Day'],format ="%d/%m/%Y")
data['month_index'] = df['Date'].dt.month
avg_temp = df[(df['Date']>='2010-03-01') & (df['Date']<='2012-05-31')].iloc[:,1]
avg_temp =sum(avg_temp)/len(avg_temp)
avg_temp = round(avg_temp,2)
avg_temp
# Out:
# 45.33

# %% [markdown]
# ### Find the range of averange temperature on Dec 2010
# * NOTE avg_temp_range should be of type of float

# %%
import datetime as dt
df['Date'] = pd.to_datetime(df['Day'],format="%d/%m/%Y")
df['month_index']= df['Date'].dt.month
min_avg_temp = df[(df['Date']>='2010-12-01') & (df['Date']<='2010-12-31')].iloc[:,1].min() 
max_avg_temp = df[(df['Date']>='2010-12-01') & (df['Date']<='2010-12-31')].iloc[:,1].max()
avg_temp_range = max_avg_temp-min_avg_temp
print("%.2f" %avg_temp_range)
# Out:
# 44.80

# %% [markdown]
# ### Out of all available records which day has the highest difference between maximum_pressure and minimum_pressure
# * assign the date in string format as 'yyyy-mm-dd'. Make sure you enclose it with single quote

# %%
import datetime as dt
df['Date'] = pd.to_datetime(df['Day'],infer_datetime_format='%Y-%m-%d')
df['month_index'] = df['Date'].dt.month

df['pressure_diff'] = df['Maximum pressure ']-df['Minimum pressure ']
max_press_diff = df['pressure_diff'].idxmax()
max_press_date = df['Date'][max_press_diff]

max_p_range_day = max_press_date.strftime('%Y-%m-%d')
max_p_range_day
# Out:
# '2018-03-23'

# %% [markdown]
# ### How many days falls under median (i.e equal to median value) of barrometer reading.
# * NOTE median_b_days should be of type of int

# %%
median_b_days = (df['Average barometer (in)'] == df['Average barometer (in)'].median()).sum()
median_b_days
# Out:
# 534

# %% [markdown]
# ### Out of all the available records how many days are within one standard deviation of average temperaturem
# * NOTE num_days_std should be of type of int

# %%
avg_temp_std = df['Average temperature (°F)'].std()
avg_temp_mean = df['Average temperature (°F)'].mean()
num_days_ = ((df['Average temperature (°F)'] > avg_temp_mean - avg_temp_std) & (df['Average temperature (°F)'] < avg_temp_mean + avg_temp_std)).sum()
num_days_std = num_days_.item()
num_days_std
# Out:
# 2092

# %%
df
# Out:
#              Day  Average temperature (°F)  Average humidity (%)  \
# 0      1/01/2009                      37.8                    35
# 1      2/01/2009                      43.2                    32
# 2      3/01/2009                      25.7                    60
# 3      4/01/2009                       9.3                    67
# 4      5/01/2009                      23.5                    30
# ...          ...                       ...                   ...
# 3275  24/10/2018                      45.9                    53
# 3276  25/10/2018                      46.7                    40
# 3277  26/10/2018                      48.4                    35
# 3278  27/10/2018                      53.3                    37
# 3279  28/10/2018                      49.4                    48
#
#       Average dewpoint (°F)  Average barometer (in)  Average windspeed (mph)  \
# 0                      12.7                    29.7                     26.4
# 1                      14.7                    29.5                     12.8
# 2                      12.7                    29.7                      8.3
# 3                       0.1                    30.4                      2.9
# 4                      -5.3                    29.9                     16.7
# ...                     ...                     ...                      ...
# 3275                   27.5                    29.8                      2.7
# 3276                   22.7                    29.8                      4.5
# 3277                   21.6                    29.8                      9.7
# 3278                   26.6                    29.8                     10.3
# 3279                   25.2                    29.9                      5.3
#
#       Average gustspeed (mph)  Average direction (°deg)  \
# 0                        36.8                       274
# 1                        18.0                       240
# 2                        12.2                       290
# 3                         4.5                        47
# 4                        23.1                       265
# ...                       ...                       ...
# 3275                      4.6                       282
# 3276                      7.2                       283
# 3277                     14.4                       283
# 3278                     14.8                       282
# 3279                      7.6                       282
#
#       Rainfall for month (in)  Rainfall for year (in)  ...  \
# 0                        0.00                    0.00  ...
# 1                        0.00                    0.00  ...
# 2                        0.00                    0.00  ...
# 3                        0.00                    0.00  ...
# 4                        0.00                    0.00  ...
# ...                       ...                     ...  ...
# 3275                     0.85                    6.86  ...
# 3276                     0.85                    6.86  ...
# 3277                     0.85                    6.86  ...
# 3278                     0.85                    6.86  ...
# 3279                     0.85                    6.86  ...
#
#       Maximum humidity (%)  Minimum humidity (%)  Maximum pressure   \
# 0                       44                    27             29.762
# 1                       43                    16             29.669
# 2                       89                    35             30.232
# 3                       79                    35             30.566
# 4                       56                    13             30.233
# ...                    ...                   ...                ...
# 3275                    81                    23             29.947
# 3276                    60                    19             29.933
# 3277                    48                    19             29.979
# 3278                    78                    24             29.935
# 3279                    90                    19             30.040
#
#       Minimum pressure   Maximum windspeed (mph)  Maximum gust speed (mph)  \
# 0                29.596                     41.4                      59.0
# 1                29.268                     35.7                      51.0
# 2                29.260                     25.3                      38.0
# 3                30.227                     12.7                      20.0
# 4                29.568                     38.0                      53.0
# ...                 ...                      ...                       ...
# 3275             29.710                     12.7                      19.6
# 3276             29.682                     13.8                      19.6
# 3277             29.759                     20.7                      31.1
# 3278             29.650                     28.8                      38.0
# 3279             29.663                     18.4                      25.3
#
#       Maximum heat index (°F)       Date  month_index  pressure_diff
# 0                        40.1 2009-01-01            1          0.166
# 1                        52.8 2009-02-01            2          0.401
# 2                        41.2 2009-03-01            3          0.972
# 3                        32.0 2009-04-01            4          0.339
# 4                        32.0 2009-05-01            5          0.665
# ...                       ...        ...          ...            ...
# 3275                     57.2 2018-10-24           10          0.237
# 3276                     61.8 2018-10-25           10          0.251
# 3277                     58.7 2018-10-26           10          0.220
# 3278                     64.5 2018-10-27           10          0.285
# 3279                     67.3 2018-10-28           10          0.377
#
# [3280 rows x 23 columns]
